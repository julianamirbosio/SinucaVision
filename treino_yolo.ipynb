# %% [markdown]
# <a href="https://colab.research.google.com/github/julianamirbosio/SinucaVision/blob/main/treino_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip -q "/content/drive/MyDrive/dataset_aumentado.zip" -d /content/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.3 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

modelo = YOLO('yolov8n.pt')
modelo.train(
    data='/content/dataset_aumentado/data.yaml',
    epochs=120,
    imgsz=640,
    batch=16,
    device=0,
    project='runs_sinuca',
    name='deteccao_bola'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.83 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/runs_sinuca/deteccao_bola/weights/best.pt')
